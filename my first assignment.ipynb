# %%
#read this dataset
# explain the key featu$es of Python that ake it a popula$ choice fo$ p$og$aing0
ANS = KEY FEATURE OF PYTHAN 
1> PYTHAN IS OBJECT-ORIENTED
  structure supports such concept as polymorphism,operation overloading and multiply inheritemce
2>  INDENTATION 
is one of the greatest feature and pythan
3>ITS A FREE:
    downloading pythan and installing pythan is free and
4> ITS POWERFUL:
    DYNAMIC TYPING
    BUILT IN TYPE AND TOOLS 
    LIBARY UTILITIES
    AUTOMATIC ME,ORY MAMNGEMENT
5> INTERPRETEND LANGUAGE:
    pythan is processed at runtime by pythan inter preter

# %%
#Desc$ibe the $ole of p$edefined keywo$ds in Python and p$ovide exaples of how they a$e used in a program

in pythan predefined keywords are recerved wards that have special meaning and are used to define the structure and logic of a program
1>assignment keywords 
-,+,*,?,%,**,#
2> logical keywords 
and or not
3>import keywords 
impory, from ,as

# %%
#0 Copa$e and cont$ast utable and iutable obects in Python with exaples0
In pythan object can be classified into two categories: mutable and immutable
MUTABLE OBJECT =  can be changed after creation modification affect the original object 
eaxample= lists ,distance:
    my=[1,2,3]
    my_list_oppend(4)
    print(my_list)#output[1,2,3,4]
IMMUTABLE OBJECT = cannot be changed after creation modification create a new object 
EZAMPLE : integers,float,string
EXAMPLE: my string="hello"
my string+="world"
print(my_string)# output: "hello world"
print(id9my_string)#different id,new
object create

# %%
#Discuss the diffe$ent types of ope$ato$s in Python and p$ovide exaples of how they a$e used0

AIRTHMATIC OPERATION: perform mathmatics opertion
+,addition
-, substraction
*,multiplication
/,division
**,exponentiation
%,modulus
EXAMPLE = X= 5+3# OUTPUT: 8
comparison operators:campare values
-==(equal to), less than 
!=(not equal to ),>greater than equal
>greater than ,less than equal

#logical operation:= combine conditional statement:
and(logical and)
or (logical or)
not(logical not)
EXAMPLE= X=5>3 AND 2<4#OUTPUT TRUE

#ASSIGNMENT OPERTORS ASSIGN VALUS TO VARIBLE
=,ASSIGNMENT)
+,ADDITION)
_,SUBSTRACTION
*,MULTIPLICATION ASSIGNMENT)
/,DIVISION ASSAIGNMENT)
#BITISE OPERTORS= PERFORM BIT-LEVEL OPERTION
&(BITWISE AND)
!(BITWISE OR)
^(BITWISE XOR0
~(BIT NOT)
  <<(LEFT SHIFT)
  >>(RIGHT SHIFT)
  #MEMBERSGIP OPERATORS:CHECK MEMBERSHIP IN A SEQUENCE =  in (membership),not in (non - membership
  example x= 2in(1,2,3)#output:true
  # identify opertors: check object #output true
  is (identify)
  is not(non identif)
  example x=(1,2,3,):y=x print(x is y)
  output:true

# %%
#0 +xplain the concept of type casting in Python with exaples0

type casting in pythan is the process of converting a varible from one data type to another .this can be dne using built
in funcation like int(),flaot(),str(),etc
example = interger to float: int_var=5;float_var=float(int_var;print(float_var)#output 5.0
  2> FLOAT TO INTEGRS ;  float_var= 5.5,int_var=int(float_var);print(int_var)#output5
                                                       3> string to integers; ste_var="5" int_var=int(str_var);print_var)#output;5
4> string to float; str_var="5.5;float_var=float(str_var):print(float_var=float(str_var);print(float_var)#output5.5

# %%
#How do conditional stateents wo$k in Python? Illust$ate with exaples

conditional state in pythan are used to exeute different blocks of code based on certain condition- they are also known as decision
making ststement
example= simple if ststement:
    x=5
    if x>10:
        print("x is greatest than 10")
        output:name(beacause x is not greater than 10)
       IF ELSE STSTEMENT
    X=5
    ifx>10:
        print("x is greater than 10")else:
            print("x is less than pr equal to10")
            output:("x is less than or equal to 10")
            IF_ELIF_ELSE STATEMENT:
                X=5
                IFX>10:
                    print("x is greater than 10")elif x==5:
                        print("x is equal to5") else:
                            print("x is less than 5")
                            output:( x is euqual to 5")
      NESTED IF STATEMENT 
              
      x=5
     if x>3:
     if x <7:
     print(x"is between 3and 7")                               
     output:("x is between 3 and 7")
                                    
        using logical operation
                                    x=5
                                    if x>3 and x<7
                                    print("x is between 3 and 7")
                                    output ("x is between 3and 7")

# %%
#0 Desc$ibe the diffe$ent types of loops in Python and thei$ use cases with exaples.

FOR LOOPS = used for iterating over a sequence (list tuple ,string,etc)or other iterable object.
syntax: for variable in iterable
...#code to execute
example= fruits =[apple ,banana, cherry]
for fruits in fruits
 use cases= iterating over a list of items reading files line by line 
    iterating over a dictionary keys on values
 

2> while loops = used for executing a block f code as long as a conditional is true 
syntax: while comdition 
       #code to execute 
    eample + i=0
    while i<5:
        print(i)
        i+=1
      use cases = repeating a task untill a condition is met 
    = implementing a countdoen or timer 
    = reading input a certain condition is met
